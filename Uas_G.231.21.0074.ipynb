# %%
#Nama : Putri Yolanda
#Nim  : G.231.21.0074
#UAS Praktikum

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#data dari CSV
data = pd.read_csv('stock.csv')

# %%
data
# Out:
#                     Stock Name Symbol  Shares  Purchase Price  Cost Basis  \
# 0                        Apple   AAPL     100            90.0      9000.0
# 1                    Microsoft   MSFT     200            32.0      6400.0
# 2                   SalesForce    CRM     150            25.0      3750.0
# 3                       Oracle   ORCL     250            50.0     12500.0
# 4   Hewlett Packard Enterprise    HPE     500            18.0      9000.0
# 5                     Alphabet   GOOG     100           225.0     22500.0
# 6                        Intel   INTC     200            22.0      4400.0
# 7                        Cisco   CSCO     225            18.0      4050.0
# 8                     Qualcomm   QCOM     185            65.0     12025.0
# 9                       Amazon   AMZN      50           800.0     40000.0
# 10                      Redhat    RHT     100            95.0      9500.0
# 11                    Facebook     FB    1000            17.0      1700.0
# ...

# %%
#Histogram untuk Purchase Price, Current Price, dan Gain/Loss
plt.figure(figsize=(14, 6))

plt.subplot(1, 4, 1)
plt.hist(data['Purchase Price'], bins=10, edgecolor='red')
plt.xlabel('Purchase Price')
plt.ylabel('Frequency')
plt.title('Histogram of Purchase Price')

plt.subplot(1, 4, 2)
plt.hist(data['Current Price'], bins=10, edgecolor='red')
plt.xlabel('Current Price')
plt.ylabel('Frequency')
plt.title('Histogram of Current Price')

plt.subplot(1, 4, 3)
plt.hist(data['Gain/Loss'], bins=10, edgecolor='red')
plt.xlabel('Gain/Loss')
plt.ylabel('Frequency')
plt.title('Histogram of Gain/Loss')

plt.tight_layout()
plt.show()

# %%
#Top 5 Stocks dengan highest Dividend/Share
top_dividend = data.nlargest(5, 'Dividend/share')[['Stock Name', 'Symbol', 'Dividend/share']]
print('Top 5 Stocks with highest Dividend/share:')
print(top_dividend)
# Out:
# Top 5 Stocks with highest Dividend/share:
#   Stock Name Symbol  Dividend/share
# 0      Apple   AAPL            2.28
# 8   Qualcomm   QCOM            2.12
# 1  Microsoft   MSFT            1.56
# 7      Cisco   CSCO            1.16
# 6      Intel   INTC            1.09

# %%
#Top 5 Stocks dengan highest Market Value
top_market_value = data.nlargest(5, 'Market Value')[['Stock Name', 'Symbol', 'Market Value']]
print('\nTop 5 Stocks with highest Market Value:')
print(top_market_value)
# Out:
# Top 5 Stocks with highest Market Value:
#    Stock Name Symbol  Market Value
# 11   Facebook     FB     141640.00
# 5    Alphabet   GOOG      83336.00
# 9      Amazon   AMZN      44882.00
# 0       Apple   AAPL      14413.27
# 1   Microsoft   MSFT      13114.14

# %%
#Top 7 Stocks dengan highest Annual Yield
top_annual_yield = data.nlargest(7, 'Annual Yield')[['Stock Name', 'Symbol', 'Annual Yield']]
print('\nTop 7 Stocks with highest Annual Yield:')
print(top_annual_yield)
# Out:
# Top 7 Stocks with highest Annual Yield:
#                    Stock Name Symbol  Annual Yield
# 8                    Qualcomm   QCOM          3.75
# 7                       Cisco   CSCO          3.49
# 6                       Intel   INTC          3.02
# 1                   Microsoft   MSFT          2.38
# 0                       Apple   AAPL          1.58
# 4  Hewlett Packard Enterprise    HPE          1.47
# 3                      Oracle   ORCL          1.44
